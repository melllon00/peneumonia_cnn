# %%
#-*-coding:utf-8-*-
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline  

img = cv2.imread('/Users/imjaegon/OneDrive/사진/IU.jpg');

hist, bins = np.histogram(img.flatten(), 256,[0,256])

cdf = hist.cumsum()

# cdf의 값이 0인 경우는 mask처리를 하여 계산에서 제외
# mask처리가 되면 Numpy 계산에서 제외가 됨
# 아래는 cdf array에서 값이 0인 부분을 mask처리함
cdf_m = np.ma.masked_equal(cdf,0)

#History Equalization 공식
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())

# Mask처리를 했던 부분을 다시 0으로 변환
cdf = np.ma.filled(cdf_m,0).astype('uint8')

img2 = cdf[img]
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.subplot(122),plt.imshow(img2),plt.title('Equalization')
plt.show()

# %%
# import keras.models as km
# from keras.utils.vis_utils import plot_model

# plot_model(km.load_model('model_plus_layer_2.h5'), to_file='model_plot_plus_layer_2.png', show_shapes=True, show_layer_names=True)

# %%
import cv2

fname = '/Users/imjaegon/OneDrive/사진/IU.jpg'

original = cv2.imread(fname, cv2.IMREAD_COLOR)
gray = cv2.imread(fname, cv2.IMREAD_GRAYSCALE)
unchange = cv2.imread(fname, cv2.IMREAD_UNCHANGED)

# cv2.imshow('Original', original)
# cv2.imshow('Gray', gray)
# cv2.imshow('Unchange', unchange)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(fname, cv2.IMREAD_COLOR)

b, g, r = cv2.split(img)   # img파일을 b,g,r로 분리
img2 = cv2.merge([r,g,b]) # b, r을 바꿔서 Merge

plt.imshow(img2)
plt.xticks([]) # x축 눈금
plt.yticks([]) # y축 눈금
plt.show()

# %%
import matplotlib.cm as cm

hist, bins = np.histogram(img.flatten(), 256,[0,256])

cdf = hist.cumsum()

# cdf의 값이 0인 경우는 mask처리를 하여 계산에서 제외
# mask처리가 되면 Numpy 계산에서 제외가 됨
# 아래는 cdf array에서 값이 0인 부분을 mask처리함
cdf_m = np.ma.masked_equal(cdf,0)

#History Equalization 공식
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())

# Mask처리를 했던 부분을 다시 0으로 변환
cdf = np.ma.filled(cdf_m,0).astype('uint8')

img3 = cdf[img2]
plt.subplot(121),plt.imshow(img2),plt.title('Original')
plt.subplot(122),plt.imshow(img3),plt.title('Equalization')
plt.show()

# %%
plt.subplot(121),plt.imshow(img2, cmap=cm.gray, vmin=0, vmax=255),plt.title('Original')
plt.subplot(122),plt.imshow(img3, cmap=cm.gray, vmin=0, vmax=255),plt.title('Equalization')
plt.show()

# %%
#-*-coding:utf-8-*-
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.pyplot as pyplot

img = cv2.imread(fname, 0 );

# OpenCV의 Equaliztion함수
img2 = cv2.equalizeHist(img)
img = cv2.resize(img,(400,400))
img2 = cv2.resize(img2,(400,400))

# dst = np.hstack((img, img2))

# %%
plt.imshow(img, cmap=cm.gray)
plt.show()

# %%
plt.imshow(img, cmap=cm.gray)
plt.show()

# %%
#-*-coding:utf-8-*-
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.pyplot as pyplot 
# %matplotlib inline  

fname = '/Users/imjaegon/OneDrive/사진/IU.jpg'
img2 = cv2.imread(fname, 0 );

# # OpenCV의 Equaliztion함수
# img2 = cv2.equalizeHist(img)
# img = cv2.resize(img,(400,400))
# img2 = cv2.resize(img2,(400,400))

# dst = np.hstack((img, img2))
hist, bins = np.histogram(img2.flatten(), 256,[0,256])

cdf = hist.cumsum()

# cdf의 값이 0인 경우는 mask처리를 하여 계산에서 제외
# mask처리가 되면 Numpy 계산에서 제외가 됨
# 아래는 cdf array에서 값이 0인 부분을 mask처리함
cdf_m = np.ma.masked_equal(cdf,0)

#History Equalization 공식
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())

# Mask처리를 했던 부분을 다시 0으로 변환
cdf = np.ma.filled(cdf_m,0).astype('uint8')

img3 = cdf[img2]
plt.subplot(121),plt.imshow(img2, cmap=cm.gray, vmin=0, vmax=255),plt.title('Original')
plt.subplot(122),plt.imshow(img3, cmap=cm.gray, vmin=0, vmax=255),plt.title('Equalization')
plt.show()

# %%
#-*-coding:utf-8-*-
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.pyplot as pyplot 
# %matplotlib inline  

fname = '/Users/imjaegon/programming/docker_share/chest_xray/train/NORMAL/IM-0115-0001.jpeg'
img2 = cv2.imread(fname, 0 );

# # OpenCV의 Equaliztion함수
# img2 = cv2.equalizeHist(img)
# img = cv2.resize(img,(400,400))
# img2 = cv2.resize(img2,(400,400))

# dst = np.hstack((img, img2))
hist, bins = np.histogram(img2.flatten(), 256,[0,256])

cdf = hist.cumsum()

# cdf의 값이 0인 경우는 mask처리를 하여 계산에서 제외
# mask처리가 되면 Numpy 계산에서 제외가 됨
# 아래는 cdf array에서 값이 0인 부분을 mask처리함
cdf_m = np.ma.masked_equal(cdf,0)

#History Equalization 공식
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())

# Mask처리를 했던 부분을 다시 0으로 변환
cdf = np.ma.filled(cdf_m,0).astype('uint8')

img3 = cdf[img2]
plt.subplot(121),plt.imshow(img2, cmap=cm.gray, vmin=0, vmax=255),plt.title('Original')
plt.subplot(122),plt.imshow(img3, cmap=cm.gray, vmin=0, vmax=255),plt.title('Equalization')
plt.show()

# %%
#-*-coding:utf-8-*-
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.pyplot as pyplot 
# %matplotlib inline  

fname = '/Users/imjaegon/programming/docker_share/chest_xray/train/NORMAL/IM-0115-0001.jpeg'
img2 = cv2.imread(fname, 0 );

# # OpenCV의 Equaliztion함수
# img2 = cv2.equalizeHist(img)
# img = cv2.resize(img,(400,400))
# img2 = cv2.resize(img2,(400,400))

# dst = np.hstack((img, img2))
hist, bins = np.histogram(img2.flatten(), 256,[0,256])

cdf = hist.cumsum()

# cdf의 값이 0인 경우는 mask처리를 하여 계산에서 제외
# mask처리가 되면 Numpy 계산에서 제외가 됨
# 아래는 cdf array에서 값이 0인 부분을 mask처리함
cdf_m = np.ma.masked_equal(cdf,0)

#History Equalization 공식
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())

# Mask처리를 했던 부분을 다시 0으로 변환
cdf = np.ma.filled(cdf_m,0).astype('uint8')

img3 = cdf[img2]
plt.subplot(121),plt.imshow(img2, cmap=cm.gray, vmin=0, vmax=255),plt.title('Original')
plt.subplot(122),plt.imshow(img3, cmap=cm.gray, vmin=0, vmax=255),plt.title('Equalization')
plt.show()

# %%
#-*-coding:utf-8-*-
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.pyplot as pyplot 
# %matplotlib inline  

fname = '/Users/imjaegon/programming/docker_share/chest_xray/train/PNEUMONIA/person1_bacteria_1.jpeg'
img2 = cv2.imread(fname, 0 );

# # OpenCV의 Equaliztion함수
# img2 = cv2.equalizeHist(img)
# img = cv2.resize(img,(400,400))
# img2 = cv2.resize(img2,(400,400))

# dst = np.hstack((img, img2))
hist, bins = np.histogram(img2.flatten(), 256,[0,256])

cdf = hist.cumsum()

# cdf의 값이 0인 경우는 mask처리를 하여 계산에서 제외
# mask처리가 되면 Numpy 계산에서 제외가 됨
# 아래는 cdf array에서 값이 0인 부분을 mask처리함
cdf_m = np.ma.masked_equal(cdf,0)

#History Equalization 공식
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())

# Mask처리를 했던 부분을 다시 0으로 변환
cdf = np.ma.filled(cdf_m,0).astype('uint8')

img3 = cdf[img2]
plt.subplot(121),plt.imshow(img2, cmap=cm.gray, vmin=0, vmax=255),plt.title('Original')
plt.subplot(122),plt.imshow(img3, cmap=cm.gray, vmin=0, vmax=255),plt.title('Equalization')
plt.show()

# %%
np.shape(img2)
# Out:
# (439, 712)
